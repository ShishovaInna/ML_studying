# %% [markdown]
# ## **Notebook_1**

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
# !dir
# Out:
#  Том в устройстве C не имеет метки.
#  Серийный номер тома: BE56-2B34
#
#  Содержимое папки C:\Users\Inna\anaconda_projects\3889cb20-a1f5-40ca-8217-6c88f6ea63e4
#
# 29.04.2026  20:48    <DIR>          .
# 29.04.2026  20:48    <DIR>          ..
# 29.04.2026  20:40    <DIR>          .ipynb_checkpoints
# 29.04.2026  20:48             1 080 my_first_notebook.ipynb
#                1 файлов          1 080 байт
#                3 папок  301 892 304 896 байт свободно

# %% [markdown]
# * Список
# - список 1
# - список 2
# ** ще один

# %%
# !pip show numpy
# Out:
# WARNING: Package(s) not found: numpy

# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.3 MB 7.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.3 MB 16.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.3 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 16.3 MB/s  0:00:00
# ...

# %%
import numpy as np

# %%
# !pip show numpy
# Out:
# Name: numpy
# Version: 2.4.4
# Summary: Fundamental package for array computing in Python
# Home-page: https://numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License-Expression: BSD-3-Clause AND 0BSD AND MIT AND Zlib AND CC0-1.0
# Location: C:\Users\Inna\anaconda3\envs\ml_studying\Lib\site-packages
# Requires:
# Required-by:

# %%
# !pip show pandas
# Out:
# WARNING: Package(s) not found: pandas

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.8 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 26.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 18.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...
